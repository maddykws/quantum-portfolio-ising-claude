# %% [markdown]
# # QPU Validation — Rigetti Cepheus-1-108Q
# ## 108-qubit superconducting QPU via Amazon Braket
#
# **Cost:** $1.44 total for two runs
#
# **Finding:** Hardware noise at current NISQ depth produces near-flat
# measurement distributions at 24-qubit scale — quantifying the
# simulation-to-hardware gap and motivating fault-tolerant quantum hardware.
#
# **Run A:** 10 qubits, p=2 — circuit execution confirmed
# **Run B:** 24 qubits, p=1 — full universe, noise characterisation
#
# **Requirements:**
# - Amazon Braket account (AWS free tier)
# - $2 in AWS credits
# - Run inside Amazon Braket notebook environment

# %%
import boto3, json, time, os
import numpy as np
import pandas as pd
import yfinance as yf
from braket.aws import AwsDevice
from braket.circuits import Circuit
print('Ready.')
