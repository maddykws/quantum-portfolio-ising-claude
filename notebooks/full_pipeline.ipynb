# %% [markdown]
# # Quantum Portfolio Optimisation
# ## NVIDIA Ising Calibration + CUDA-Q + Claude AI
#
# **Results:** 373x GPU speedup · +3.1% vs top-N · 1.4M× sampling efficiency
#
# **Stack:** NVIDIA CUDA-Q · NVIDIA Ising Calibration · Claude AI · Google Colab L4
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/maddykws/quantum-portfolio-ising-claude/blob/main/notebooks/full_pipeline.ipynb)
#
# ---
#
# **Note:** Download the full notebook from Google Drive and replace this file,
# or run directly in Colab using the badge above.

# %%
# Install required packages
# !pip install cudaq anthropic yfinance scipy matplotlib -q

# %%
# Set API keys
import os
os.environ['NVIDIA_API_KEY']    = 'your_nvapi_key_here'
os.environ['ANTHROPIC_API_KEY'] = 'your_anthropic_key_here'
